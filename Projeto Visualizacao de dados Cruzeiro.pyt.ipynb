# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
acoes = ('DMMO3', 'CIEL3', 'CURY3', 'MILS3', 'RECV3', 'PRIO3', 'BBSE3', 'KEPL3', 'HYPE3', 'LLIS3' )
retorno = [269.23, 142.09, 94.53, 84.66, 81.97, 80.02, 74.88, 70.76, 64.74, 54.64,]
plt.bar (acoes,retorno)
plt.ylabel('Retorno no ano (%)')
plt.xlabel('Código do ativo')
plt.title('As 10 ações que mais valorizaram em 2022')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Meses = ('Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez') 
Valorizacao = [0.49, 1.03, 0.92, 1.27, 1.69, 1.36, 1.47, 1.59, 1.74, 1.76, 1.87, 1.92]
plt.plot(Meses, Valorizacao)
plt.ylabel('Reais')
plt.xlabel('Meses')
plt.title('Valorização DMMO3 em 2022')
plt.show()

# %%
vals = [3, 2, 1, 1, 1, 1, 1]
labels = ['Petroleo e Gás', 'Imobiliário e Construção', 'Financeiro', 'Seguros', 'Industrial', 'Farmaceutico', 'Consumo e varejo']
fig, ax = plt.subplots(figsize=(12, 5))
ax.pie(vals, labels=labels)
ax.set_title('Setores das 10 ações que mais valorizaram em 2022')
plt.show()
